# %% [markdown]
# <a href="https://colab.research.google.com/github/yashmundhada/BankNote-authentication/blob/main/BankNote_Authentication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
dataset=pd.read_csv('BankNote_Authentication.csv')

# %%
print(dataset.columns)
# Out:
# Index(['variance', 'skewness', 'curtosis', 'entropy', 'class'], dtype='object')

# %%
dataset.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %% [markdown]
# ## **Preprocessing Dataset**
# ### 1. Checking the correctness of dataset by checking any other value of class from bottom

# %%
dataset.tail()
# Out:
#       variance  skewness  curtosis  entropy  class
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1

# %% [markdown]
# Since we have to identify whether a note bundle is fake or real therefore we set our target variable as class
#
# ```
# 0 = FAKE
#
# 1 = REAL
# ```

# %%
print("Shape of Dataset:\n", dataset.shape)  #number of rows and column
print("\n")
dataset.info()
# Out:
# Shape of Dataset:
#  (1372, 5)
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   variance  1372 non-null   float64
#  1   skewness  1372 non-null   float64
#  2   curtosis  1372 non-null   float64
#  3   entropy   1372 non-null   float64
#  4   class     1372 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %% [markdown]
# ### 2. Checking distribution of dataset

# %%
sns.boxplot(data=dataset.iloc[:,:-1], palette="Set1")   #range
plt.rcParams['figure.figsize'] = [15, 10]

# %% [markdown]
# ### 3. Checking correlation in the dataset

# %%
correlationVal = dataset.corr()

# producing a heatmap for correlation values of dataset
correlationVal.style.background_gradient(cmap='PuBu', low=0, high=0, axis=0, subset=None)
# Out:
# <style  type="text/css" >
# #T_53525fa6_49c2_11ec_89c3_0242ac1c0002row0_col0,#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row1_col1,#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row2_col2,#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row3_col3,#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row4_col4{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row0_col1{
#             background-color:  #4897c4;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row0_col2{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row0_col3{
#             background-color:  #67a4cc;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row0_col4,#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row1_col2,#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row1_col3,#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row2_col1,#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row4_col0{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row1_col0{
#             background-color:  #509ac6;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row1_col4{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row2_col0{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row2_col3{
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row2_col4{
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row3_col0{
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row3_col1{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row3_col2{
#             background-color:  #3991c1;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row3_col4{
#             background-color:  #99b8d8;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row4_col1{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row4_col2{
#             background-color:  #65a3cb;
#             color:  #000000;
#         }#T_53525fa6_49c2_11ec_89c3_0242ac1c0002row4_col3{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }</style><table id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >variance</th>        <th class="col_heading level0 col1" >skewness</th>        <th class="col_heading level0 col2" >curtosis</th>        <th class="col_heading level0 col3" >entropy</th>        <th class="col_heading level0 col4" >class</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002level0_row0" class="row_heading level0 row0" >variance</th>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row0_col1" class="data row0 col1" >0.264026</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row0_col2" class="data row0 col2" >-0.380850</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row0_col3" class="data row0 col3" >0.276817</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row0_col4" class="data row0 col4" >-0.724843</td>
#             </tr>
#             <tr>
#                         <th id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002level0_row1" class="row_heading level0 row1" >skewness</th>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row1_col0" class="data row1 col0" >0.264026</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row1_col2" class="data row1 col2" >-0.786895</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row1_col3" class="data row1 col3" >-0.526321</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row1_col4" class="data row1 col4" >-0.444688</td>
#             </tr>
#             <tr>
#                         <th id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002level0_row2" class="row_heading level0 row2" >curtosis</th>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row2_col0" class="data row2 col0" >-0.380850</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row2_col1" class="data row2 col1" >-0.786895</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row2_col3" class="data row2 col3" >0.318841</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row2_col4" class="data row2 col4" >0.155883</td>
#             </tr>
#             <tr>
#                         <th id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002level0_row3" class="row_heading level0 row3" >entropy</th>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row3_col0" class="data row3 col0" >0.276817</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row3_col1" class="data row3 col1" >-0.526321</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row3_col2" class="data row3 col2" >0.318841</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row3_col4" class="data row3 col4" >-0.023424</td>
#             </tr>
#             <tr>
#                         <th id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002level0_row4" class="row_heading level0 row4" >class</th>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row4_col0" class="data row4 col0" >-0.724843</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row4_col1" class="data row4 col1" >-0.444688</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row4_col2" class="data row4 col2" >0.155883</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row4_col3" class="data row4 col3" >-0.023424</td>
#                         <td id="T_53525fa6_49c2_11ec_89c3_0242ac1c0002row4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Findings:**
#
# 1. Data is well distributed as we can see in box plot which thus gives class prediction in the set { 0, 1 }.
# 2. Variance and Skewness has an inverse effect on Class label as negative correlation.
# 3. Variance and Skewness has the maximum effect on Class label. We will plot all the graphs considering these two variables.

# %% [markdown]
#  ##**Python pyspark**
#
# The vision is to include the power of Distributed Computing which is provided in the **pyspark** library in Python built alongside Apache Spark community. Since we aim to include parallelism in the library and its functions will prove helpful in helping us achieve false note detection efficiently.

# %%
pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.2.0.tar.gz (281.3 MB)
#      |████████████████████████████████| 281.3 MB 38 kB/s
# Collecting py4j==0.10.9.2
#   Downloading py4j-0.10.9.2-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 37.6 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.0-py2.py3-none-any.whl size=281805912 sha256=a6bc3dbd19244b82f663a430a4a30c7f5db2cbf86af6d72f658275c0ba0f3aec
#   Stored in directory: /root/.cache/pip/wheels/0b/de/d2/9be5d59d7331c6c2a7c1b6d1a4f463ce107332b1ecd4e80718
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.2 pyspark-3.2.0

# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession

# %% [markdown]
# SparkContext() is basically the entry point similar to object initiation in OOPS
#
# SparkSession() is for the use of inner disributed features of system essential for disributed computing

# %%
sc = SparkContext.getOrCreate();
spark = SparkSession(sc)

# %% [markdown]
# ### 1. Conversion of Dataset(curently in Python Dataframe) to Python Numpy Arrays
#
# The below is performed since training and testing of dataset requires data to be in numpy array format

# %%
print("4 Variables determing o/p")
X=dataset.iloc[:,0:4].values
print(X)

print("\nClass values")
Y=dataset.iloc[:,-1].values
print(Y)
# Out:
# 4 Variables determing o/p
# [[  3.6216    8.6661   -2.8073   -0.44699]
#  [  4.5459    8.1674   -2.4586   -1.4621 ]
#  [  3.866    -2.6383    1.9242    0.10645]
#  ...
#  [ -3.7503  -13.4586   17.5932   -2.7771 ]
#  [ -3.5637   -8.3827   12.393    -1.2823 ]
#  [ -2.5419   -0.65804   2.6842    1.1952 ]]
#
# Class values
# [0 0 0 ... 1 1 1]

# %% [markdown]
# ### 2. Dataset division into Training and Testing

# %% [markdown]
# We'll be performing Logistic Regression which is a technique used model the probability of a certain class or event existing such as pass/fail, win/lose, alive/dead or healthy/sick.
#
# Here if class value returned:
#
# 0 = FAKE
#
# 1 = REAL

# %% [markdown]
# ### 3. Importing Necessary Libs

# %%
from pyspark.mllib.regression import LabeledPoint
from pyspark.mllib.classification import LogisticRegressionWithLBFGS,SVMWithSGD,LogisticRegressionWithSGD,NaiveBayes

# %%
X_train,X_test,y_train,y_test=train_test_split(X, Y, test_size=0.2, random_state=3)

# %%
data=[]
for i in range(len(X_train)):
    data.append(LabeledPoint(y_train[i],X_train[i]))

# %%
print(data[:10])
# Out:
# [LabeledPoint(0.0, [2.9719,6.8369,-0.2702,0.71291]), LabeledPoint(1.0, [-0.90784,-7.9026,6.7807,0.34179]), LabeledPoint(1.0, [-0.97325,-6.4168,5.6026,1.0323]), LabeledPoint(1.0, [-1.3414,-1.9162,-0.15538,-0.11984000000000002]), LabeledPoint(1.0, [-0.0012852,0.13863,-0.19651,0.0081754]), LabeledPoint(0.0, [-1.8411,10.8306,2.7689999999999997,-3.0901]), LabeledPoint(1.0, [-1.8974,3.5074,-1.7842,-3.8491]), LabeledPoint(1.0, [-2.3629,-0.10554000000000001,1.9336,1.1358]), LabeledPoint(1.0, [-2.3147,3.6668,-0.6969,-1.2474]), LabeledPoint(0.0, [1.9358,8.1654,-0.023425,-2.2586])]

# %%
dic={}


lrm1 = LogisticRegressionWithLBFGS.train(sc.parallelize(data), iterations=1000)     
y_predict=lrm1.predict(sc.parallelize(X_test)).collect()
cm=confusion_matrix(y_true=y_test,y_pred=y_predict)
acc=accuracy_score(y_test,y_predict)
dic["Logistic Regression With LBFGS"]=acc
print("The confusion matrix is:")
print("")
print(cm)
print("")
print("The accuracy of the {} is: {}%".format("Logistic Regression With LBFGS",acc*100))
y_whole=lrm1.predict(sc.parallelize(X)).collect()
plt.figure(3)
for i in range(len(X)):
    if(y_whole[i]==1):
        plt.scatter(X[i][0],X[i][1],color="blue")
    if(y_whole[i]==0):
        plt.scatter(X[i][0],X[i][1],color="red")
plt.title("Observation after training the spark model.")
plt.xlabel("Variance")
plt.ylabel("Skewness")
plt.show()
# Out:
# The confusion matrix is:
#
# [[168   0]
#  [  8  99]]
#
# The accuracy of the Logistic Regression With LBFGS is: 97.0909090909091%

# %%
lrm2 = LogisticRegressionWithSGD.train(sc.parallelize(data), iterations=1000)
y_predict=lrm2.predict(sc.parallelize(X_test)).collect()
cm=confusion_matrix(y_true=y_test,y_pred=y_predict)
acc=accuracy_score(y_test,y_pred=y_predict)
dic["Logistic Regression With SGD"]=acc
print("The confusion matrix is:")
print("")
print(cm)
print("")
print("The accuracy of the {} is: {}%".format("Logistic Regression With SGD",acc*100))

y_whole=lrm2.predict(sc.parallelize(X)).collect()
plt.figure(3)
for i in range(len(X)):
    if(y_whole[i]==1):
        plt.scatter(X[i][0],X[i][1],color="blue")
    if(y_whole[i]==0):
        plt.scatter(X[i][0],X[i][1],color="red")
plt.title("Observation after training the spark model.")
plt.xlabel("Variance")
plt.ylabel("Skewness")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/pyspark/mllib/classification.py:327: FutureWarning: Deprecated in 2.0.0. Use ml.classification.LogisticRegression or LogisticRegressionWithLBFGS.
#   "LogisticRegressionWithLBFGS.", FutureWarning)
# The confusion matrix is:
#
# [[168   0]
#  [  8  99]]
#
# The accuracy of the Logistic Regression With SGD is: 97.0909090909091%

# %%
lrm3 = SVMWithSGD.train(sc.parallelize(data), iterations=1000)
y_predict=lrm3.predict(sc.parallelize(X_test)).collect()
cm=confusion_matrix(y_true=y_test,y_pred=y_predict)
acc=accuracy_score(y_test,y_pred=y_predict)
dic["SVM With SGD"]=acc
print("The confusion matrix is:")
print("")
print(cm)
print("")
print("The accuracy of the {} is: {}%".format("SVM With SGD",acc*100))
y_whole=lrm3.predict(sc.parallelize(X)).collect()
plt.figure(3)
for i in range(len(X)):
    if(y_whole[i]==1):
        plt.scatter(X[i][0],X[i][1],color="blue")
    if(y_whole[i]==0):
        plt.scatter(X[i][0],X[i][1],color="red")
plt.title("Observation after training the spark model.")
plt.xlabel("Variance")
plt.ylabel("Skewness")
plt.show()
# Out:
# The confusion matrix is:
#
# [[168   0]
#  [  9  98]]
#
# The accuracy of the SVM With SGD is: 96.72727272727273%

# %%
from pyspark.mllib.tree import RandomForest
lrm4 = RandomForest.trainClassifier(sc.parallelize(data),2,{},100)
y_predict=lrm4.predict(sc.parallelize(X_test)).collect()
cm=confusion_matrix(y_true=y_test,y_pred=y_predict)
acc=accuracy_score(y_test,y_pred=y_predict)
dic["Random Forest"]=acc
print("The confusion matrix is:")
print("")
print(cm)
print("")
print("The accuracy of the {} is: {}%".format("Random Forest",acc*100))
y_whole=lrm4.predict(sc.parallelize(X)).collect()
plt.figure(3)
for i in range(len(X)):
    if(y_whole[i]==1):
        plt.scatter(X[i][0],X[i][1],color="blue")
    if(y_whole[i]==0):
        plt.scatter(X[i][0],X[i][1],color="red")
plt.title("Observation after training the spark model.")
plt.xlabel("Variance")
plt.ylabel("Skewness")
plt.show()
# Out:
# The confusion matrix is:
#
# [[158  10]
#  [  2 105]]
#
# The accuracy of the Random Forest is: 95.63636363636364%

# %%
Estimators=[]
Accuracy=[]
for i in dic:
    Estimators.append(i)
    Accuracy.append(dic[i]*100)
d={'Estimators':Estimators,"Accuracy":Accuracy}
df=pd.DataFrame(data=d)
plt.rcParams['figure.figsize'] = [10, 5]
plt.ylim(0,110)
plt.title("All classification estimators with accuracy score")
bars=plt.bar(x=Estimators,height=Accuracy)
for bar in bars:
    yval = round(bar.get_height(),2)
    plt.text(bar.get_x()+0.2, round((yval + .005),2), yval)
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# Checking of the Unlabeled Notes
# Since We can deduce that the notes which are real and considered as fake has a huge impact on the economy as the real notes are being discarded considered as fake notes. i.e.
#
# Actual Value of note: - 1
#
# Predicted Value of note: - 0
#
# We will check the notes which are labeled as fakes and are actually real by the different models and determine whether the different models capture and labeled these notes correctly.

# %% [markdown]
# Using Logistic Regression With LBFGS

# %%
y_wrong_lbfgs=[]
y_whole_lbfgs=lrm1.predict(sc.parallelize(X_test)).collect()
for i in range(len(y_whole_lbfgs)):                              
    if(y_test[i]==1 and y_whole_lbfgs[i]==0):                           #actual_value_of_note=1 && predicted_value_of_note=1
        y_wrong_lbfgs.append(X_test[i])
y_wrong_lbfgs=np.array(y_wrong_lbfgs)
print(y_wrong_lbfgs)
print("*"*45)
# Out:
# [[ 0.24394   1.4733   -1.4192   -0.58535 ]
#  [ 0.50225   0.65388  -1.1793    0.39998 ]
#  [ 0.518     0.25865  -0.84085   0.96118 ]
#  [ 0.84546   3.4826   -3.6307   -1.3961  ]
#  [ 1.3403    4.1323   -4.7018   -2.5987  ]
#  [ 0.12126   0.22347  -0.47327   0.97024 ]
#  [-1.4375   -1.8624    4.026     0.55127 ]
#  [ 0.66365  -0.045533 -0.18794   0.23447 ]]
# *********************************************

# %% [markdown]
# Using Logistic Regression With SGD

# %%
y_wrong_sgd=[]
y_whole_sgd=lrm2.predict(sc.parallelize(y_wrong_lbfgs)).collect()
for i in range(len(y_whole_sgd)):
    if(y_whole_sgd[i]==0):
        y_wrong_sgd.append(y_wrong_lbfgs[i])
y_wrong_sgd=np.array(y_wrong_sgd)
print(y_wrong_sgd)
print("*"*45)
# Out:
# [[ 0.24394   1.4733   -1.4192   -0.58535 ]
#  [ 0.50225   0.65388  -1.1793    0.39998 ]
#  [ 0.518     0.25865  -0.84085   0.96118 ]
#  [ 0.84546   3.4826   -3.6307   -1.3961  ]
#  [ 1.3403    4.1323   -4.7018   -2.5987  ]
#  [ 0.12126   0.22347  -0.47327   0.97024 ]
#  [ 0.66365  -0.045533 -0.18794   0.23447 ]]
# *********************************************

# %% [markdown]
# Using SVM With SGD

# %%
y_wrong_svm=[]
y_whole_svm=lrm3.predict(sc.parallelize(y_wrong_sgd)).collect()
for i in range(len(y_whole_svm)):
    if(y_whole_svm[i]==0):
        y_wrong_svm.append(y_wrong_sgd[i])
y_wrong_svm=np.array(y_wrong_svm)
print(y_wrong_svm)
print("*"*45)
# Out:
# [[ 0.24394   1.4733   -1.4192   -0.58535 ]
#  [ 0.50225   0.65388  -1.1793    0.39998 ]
#  [ 0.518     0.25865  -0.84085   0.96118 ]
#  [ 0.84546   3.4826   -3.6307   -1.3961  ]
#  [ 1.3403    4.1323   -4.7018   -2.5987  ]
#  [ 0.12126   0.22347  -0.47327   0.97024 ]
#  [ 0.66365  -0.045533 -0.18794   0.23447 ]]
# *********************************************

# %% [markdown]
# Using Random Forest

# %%
y_wrong_forest=[]
y_whole_forest=lrm4.predict(sc.parallelize(y_wrong_svm)).collect()
for i in range(len(y_whole_forest)):
    if(y_whole_forest[i]==0):                                                   
        y_wrong_forest.append(y_wrong_svm[i])
y_wrong_forest=np.array(y_wrong_forest)
print(y_wrong_forest)
print("*"*45)
# Out:
# [[ 0.66365  -0.045533 -0.18794   0.23447 ]]
# *********************************************

# %% [markdown]
# We can conclude that using **Random Forest** we can detect most of the real notes which are labeled as fake notes and will be discarded.
